# %%
import pandas as pd
import csv
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv(r'C:\Users\melinadiaz\Downloads\Median Salary By Race.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       62 non-null     int64
#  1   Total Women                62 non-null     int64
#  2   Total Men                  62 non-null     int64
#  3   White Women                55 non-null     float64
#  4   White Men                  55 non-null     float64
#  5   Black Women                55 non-null     float64
#  6   Black Men                  55 non-null     float64
#  7   Asian Women                34 non-null     float64
#  8   Asian Men                  34 non-null     float64
#  9   Hispanic Women             48 non-null     float64
#  10  Hispanic Men               48 non-null     float64
#  11  White, non-Hispanic Women  35 non-null     float64
#  12  White, non-Hispanic Men    35 non-null     float64
# ...

# %%
df
# Out:
#     Year  Total Women  Total Men  White Women  White Men  Black Women  \
# 0   1960        24673      40665          NaN        NaN          NaN
# 1   1961        24862      41962          NaN        NaN          NaN
# 2   1962        25338      42729          NaN        NaN          NaN
# 3   1963        25820      43803          NaN        NaN          NaN
# 4   1964        26514      44826          NaN        NaN          NaN
# ..   ...          ...        ...          ...        ...          ...
# 57  2016        44270      55015      44858.0    55638.0      38595.0
# 58  2017        43779      54385      44820.0    55810.0      38312.0
# 59  2017        44449      54427      47116.0    56083.0      38593.0
# 60  2018        45914      56293      46592.0    57389.0      38725.0
# 61  2019        47299      57456      48845.0    60017.0      41098.0
#
#     Black Men  Asian Women  Asian Men  Hispanic Women  Hispanic Men  \
# ...

# %%
fig,ax=plt.subplots(1)
plt.xticks(rotation=45)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
ax.plot(df[df["Year"]>1999]["Year"],df[df["Year"]>1999]["Total Men"], label="Men", color="blue")
ax.plot(df[df["Year"]>1999]["Year"],df[df["Year"]>1999]["Total Women"], label="Women", color="red")

# %%
ax.set(xlabel="Year", ylabel="Median Salary",xticks=df[df["Year"]>1999]["Year"])

ax.legend()
fig

# %%
fig,ax=plt.subplots(1)
plt.xticks(rotation=45) 
columns=['White Women', 'White Men',
       'Black Women', 'Black Men', 'Asian Women', 'Asian Men',
       'Hispanic Women', 'Hispanic Men', 'White, non-Hispanic Women',
       'White, non-Hispanic Men']
for i in columns:
    ax.plot(df[df["Year"]>1999]["Year"],df[df["Year"]>1999][i], label=i)

# %%
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set(xlabel="Year", ylabel="Median Salary", xticks=df[df["Year"]>1999]["Year"])
fig
