# %%
pip install xlrd
# Out:
# ...
# WARNING: You are using pip version 20.2.1; however, version 22.0.2 is available.
# You should consider upgrading via the 'c:\users\melinadiaz\appdata\local\programs\python\python38-32\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import csv
import seaborn as sns
df = pd.read_csv(r'C:\Users\melinadiaz\Downloads\MWEbyGender.csv')

# %%
df
# Out:
#     Year      Quarter       Date Number of Workers Number of Men Workers   \
# 0   2012  4th quarter  10/1/2012           103,748                 57,772
# 1   2013  1st quarter   1/1/2013           103,928                 57,884
# 2   2013  2nd quarter   4/1/2013           103,988                 57,944
# 3   2013  3rd quarter   7/1/2013           104,400                 58,082
# 4   2013  4th quarter  10/1/2013           104,764                 58,095
# 5   2014  1st quarter   1/1/2014           105,633                 58,682
# 6   2014  2nd quarter   4/1/2014           106,342                 59,486
# 7   2014  3rd quarter   7/1/2014           106,726                 59,543
# 8   2014  4th quarter  10/1/2014           107,436                 60,123
# 9   2015  1st quarter   1/1/2015           108,448                 60,346
# 10  2015  2nd quarter   4/1/2015           108,541                 60,386
# 11  2015  3rd quarter   7/1/2015           109,315                 61,004
# ...

# %%
import datetime
format_str = '%m/%d/%Y' # The format
for i in range(36):
    df["Date"][i] = datetime.datetime.strptime(df["Date"][i], format_str).date()
# Out:
# <ipython-input-99-f0523ae37d1b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Date"][i] = datetime.datetime.strptime(df["Date"][i], format_str).date()

# %%
df["Median Weekly Earnings"]=df["Median Weekly Earnings"].str.replace(',',"").astype(int)
df["Median Weekly Earnings Men"]=df["Median Weekly Earnings Men"].str.replace(',',"").astype(int)
MWE_w=df["Median Weekly Earnings Women"].tolist()
MWE_m=df["Median Weekly Earnings Men"].tolist()
MWE=df["Median Weekly Earnings"].tolist()

# %%
df["Number of Workers"]=df["Number of Workers"].str.replace(',',"").astype(int)
df["Number of Men Workers "]=df["Number of Men Workers "].str.replace(',',"").astype(int)
df["Number of Women Workers"]=df["Number of Women Workers"].str.replace(',',"").astype(int)

# %%
NW_w=df["Number of Women Workers"].tolist()
NW_m=df["Number of Men Workers "].tolist()
NW=df["Number of Workers"].tolist()

# %%
fig,ax=plt.subplots(1,1)
ax.plot(date,NW, label="Total Workers")
ax.plot(date,NW_m, label="Male Workers")
ax.plot(date,NW_w, label="Female Workers")
ax.set(title="Number of Full-Time Workers in the U.S. 2012-2021 by Sex",ylabel="in thousands")
ax.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np
fig,ax=plt.subplots(1,1)
ax.plot(date,MWE, label="Median Weekly Earnings")
ax.plot(date,MWE_m, label="Median Weekly Earnings of Men")
ax.plot(date,MWE_w, label="Median Weekly Earnings of Women")
ax.set(title="Median Weekly Earnings in the U.S. 2012-2021 by Sex",ylabel="in thousands")
ax.legend()
